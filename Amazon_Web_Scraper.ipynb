# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
def get_title(soup):

    try:
        
        title = soup.find("span", attrs={"id":'productTitle'})
        
        
        title_value = title.text

        
        title_string = title_value.strip()

    except AttributeError:
        title_string = ""

    return title_string


def get_price(soup):

    try:
        price = soup.find("span", attrs={'id':'priceblock_ourprice'}).string.strip()

    except AttributeError:

        try:
            price = soup.find("span", attrs={'id':'priceblock_dealprice'}).string.strip()

        except:
            price = ""

    return price

def get_rating(soup):

    try:
        rating = soup.find("i", attrs={'class':'a-icon a-icon-star a-star-4-5'}).string.strip()
    except AttributeError:
        try:
            rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
        except:
            rating = ""	

    return rating


def get_review_count(soup):
    try:
        review_count = soup.find("span", attrs={'id':'acrCustomerReviewText'}).string.strip()

    except AttributeError:
        review_count = ""	

    return review_count


def get_availability(soup):
    try:
        available = soup.find("div", attrs={'id':'availability'})
        available = available.find("span").string.strip()

    except AttributeError:
        available = "Not Available"	

    return available

# %%
if __name__ == '__main__':

     
    HEADERS = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36', 'Accept-Language': 'en-US, en;q=0.5'})

    
    URL = "https://www.amazon.com/s?k=playstation+4&ref=nb_sb_noss_2"

    
    webpage = requests.get(URL, headers=HEADERS)

    
    soup = BeautifulSoup(webpage.content, "html.parser")

    
    links = soup.find_all("a", attrs={'class':'a-link-normal s-no-outline'})

    
    links_list = []

    
    for link in links:
            links_list.append(link.get('href'))

    d = {"title":[], "price":[], "rating":[], "reviews":[],"availability":[]}
    
     
    for link in links_list:
        new_webpage = requests.get("https://www.amazon.com" + link, headers=HEADERS)

        new_soup = BeautifulSoup(new_webpage.content, "html.parser")

        
        d['title'].append(get_title(new_soup))
        d['price'].append(get_price(new_soup))
        d['rating'].append(get_rating(new_soup))
        d['reviews'].append(get_review_count(new_soup))
        d['availability'].append(get_availability(new_soup))

    
    amazon_df = pd.DataFrame.from_dict(d)
    amazon_df['title'].replace('', np.nan, inplace=True)
    amazon_df = amazon_df.dropna(subset=['title'])
    amazon_df.to_csv("amazon_data.csv", header=True, index=False)

# %%
amazon_df
# Out:
#                                                 title price  \
# 0   Playstation Sony 4, 500GB Slim System [CUH-221...
# 1              Sony Playstation PS4 1TB Black Console
# 2                      PlayStation 4 Slim 1TB Console
# 3   DualShock 4 Wireless Controller for PlayStatio...
# 4          Sony Playstation 4 Dual Shock 4 Controller
# 5   DualShock 4 Wireless Controller for PlayStatio...
# 6   DualShock 4 Wireless Controller for PlayStatio...
# 7   eeidc 2 Pack Wireless Controller for PS4, Remo...
# 8   TOPAD Remote Replace for PS4 Controller,Gamepa...
# 9   Wireless Controller for PS4/Pro/Slim Consoles，...
# 10  SAMINRA Replacement for PS4 Controller with 2 ...
# 11  RPlay Play-Station 4 PS4 1TB Slim Edition Jet ...
# 12  PlayStation 4 500GB Console [Old Model][Discon...
# 13  Sony PlayStation 4 Pro 1TB Console - Black (PS...
# 14  Dragon Ball Xenoverse 2 - PlayStation 4 Day On...
# 15             Sony PlayStation 4 Pro 1TB White (PS4)
# 16  PS 4 Slim Seyted Upgraded 2TB Console with Wir...
# 17  PlayStation PS5 Console – God of War Ragnarök ...
# 18       Tony Hawk's Pro Skater 1 + 2 - PlayStation 4
# 19  Hasbro Family Fun Pack - PlayStation 4 Standar...
# 20                    Sonic Frontiers - PlayStation 4
# 21                           NBA 2K23 - PlayStation 4
# 22               PAC-MAN World Re-PAC - PlayStation 4
# 23    Crash Bandicoot N. Sane Trilogy - PlayStation 4
# 24  Monster Jam Steel Titans - PlayStation 4 Stand...
# 25           LEGO Star Wars: The Skywalker Saga (PS4)
# 26  PS4 Controller Charger Dock Station, OIVO PS4 ...
# 27  BENGOO G9000 Stereo Gaming Headset for PS4 PC ...
# 28  OIVO PS4 Stand Cooling Fan Station for Playsta...
# 29  Seagate (STGD2000100) Game Drive for PS4 Syste...
# 30  Prodico PS4 Keyboard 2.4G Wireless Chatpad for...
# 31  PS4 Stand Cooling Fan for PS4 Slim/PS4 Pro/Pla...
# 32  PS4 Controller Charger, PS4 Charger USB Chargi...
# 33  PS4 Controller Charger Charging Cable 10ft 2 P...
# 34  DualShock 4 Wireless Controller for PlayStatio...
# 35  Skylanders SWAP Force Starter Pack - PlayStati...
# 36  eeidc 2 Pack Wireless Controller for PS4, Remo...
# 37  DualShock 4 Wireless Controller for PlayStatio...
# 38         Sony Playstation 4 Dual Shock 4 Controller
# 39  DualShock 4 Wireless Controller for PlayStatio...
# 40  DOYO 1080° Gaming Racing Wheel with Pedals and...
# 41  PS4 Fan Cooling Fan with Controller Charger Co...
# 42                    Sonic Frontiers - PlayStation 4
# 43                           Aliens: Dark Descent PS4
# 44                 Sonic Origins Plus - PlayStation 4
#
#                                          rating          reviews  \
# 0                            4.5 out of 5 stars      308 ratings
# 1                            4.7 out of 5 stars    1,034 ratings
# 2                            4.7 out of 5 stars   15,397 ratings
# 3                            4.7 out of 5 stars  145,566 ratings
# 4                            4.6 out of 5 stars    2,282 ratings
# 5                            4.7 out of 5 stars  145,566 ratings
# 6                            4.7 out of 5 stars  145,566 ratings
# 7                            5.0 out of 5 stars        5 ratings
# 8                            5.0 out of 5 stars        2 ratings
# 9                            4.3 out of 5 stars      152 ratings
# 10                           4.1 out of 5 stars      107 ratings
# 11                           4.8 out of 5 stars        8 ratings
# 12                           4.6 out of 5 stars   13,659 ratings
# 13                           4.5 out of 5 stars    4,204 ratings
# 14                           4.5 out of 5 stars      319 ratings
# 15                           4.4 out of 5 stars      939 ratings
# 16                           4.3 out of 5 stars       67 ratings
# 17                           4.8 out of 5 stars    6,743 ratings
# 18                           4.7 out of 5 stars    4,266 ratings
# 19                           4.5 out of 5 stars    2,711 ratings
# 20                           4.8 out of 5 stars      459 ratings
# 21                           4.7 out of 5 stars    1,384 ratings
# 22                           4.7 out of 5 stars      208 ratings
# 23                           4.7 out of 5 stars    2,599 ratings
# 24                           4.5 out of 5 stars    2,801 ratings
# 25                           4.7 out of 5 stars      483 ratings
# 26                           4.7 out of 5 stars   31,627 ratings
# 27                           4.3 out of 5 stars   98,436 ratings
# 28                           4.5 out of 5 stars   42,007 ratings
# 29                           4.8 out of 5 stars   41,550 ratings
# 30                           4.0 out of 5 stars      614 ratings
# 31                           4.3 out of 5 stars    1,328 ratings
# 32                           4.7 out of 5 stars   22,082 ratings
# 33                           4.6 out of 5 stars   17,663 ratings
# 34                           4.7 out of 5 stars  145,566 ratings
# 35                           4.4 out of 5 stars      337 ratings
# 36                           5.0 out of 5 stars        5 ratings
# 37                           4.7 out of 5 stars  145,566 ratings
# 38                           4.6 out of 5 stars    2,282 ratings
# 39                           4.7 out of 5 stars  145,566 ratings
# 40                           3.9 out of 5 stars      530 ratings
# 41                           4.3 out of 5 stars    1,328 ratings
# 42                           4.8 out of 5 stars      459 ratings
# 43  Previous page of related Sponsored Products
# 44  Previous page of related Sponsored Products
#
#                                     availability
# 0                                  Not Available
# 1                                  Not Available
# 2
# 3                                  Not Available
# 4                                  Not Available
# 5                                  Not Available
# 6                                  Not Available
# 7                                  Not Available
# 8                                  Not Available
# 9                                  Not Available
# 10                                 Not Available
# 11                                 Not Available
# 12             Only 2 left in stock - order soon
# 13             Only 1 left in stock - order soon
# 14             Only 1 left in stock - order soon
# 15             Only 1 left in stock - order soon
# 16                                 Not Available
# 17                                      In Stock
# 18                                 Not Available
# 19                                 Not Available
# 20                                      In Stock
# 21                                      In Stock
# 22                                      In Stock
# 23                                 Not Available
# 24                                      In Stock
# 25                                 Not Available
# 26                                 Not Available
# 27                                 Not Available
# 28                                 Not Available
# 29                                      In Stock
# 30                                 Not Available
# 31                                 Not Available
# 32                                 Not Available
# 33                                 Not Available
# 34                                 Not Available
# 35                                 Not Available
# 36                                 Not Available
# 37                                 Not Available
# 38                                 Not Available
# 39                                 Not Available
# 40                                 Not Available
# 41                                 Not Available
# 42                                      In Stock
# 43  This item will be released on June 20, 2023.
# 44  This item will be released on June 23, 2023.
